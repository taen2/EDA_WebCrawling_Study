# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get('https://maple.inven.co.kr/dataninfo/item/list.php?class2=101')

# %%
firststep = driver.find_element(By.CSS_SELECTOR, 'ul:nth-child(1) > li:nth-child(1) > span > a')
firststep.click()

# %%
from bs4 import BeautifulSoup
req = driver.page_source
soup = BeautifulSoup(req, 'html.parser')

# %%
# 무기류 첫번째 줄
driver.find_element(By.CSS_SELECTOR, 'ul:nth-child(1) > li:nth-child(11) > span').text
# Out:
# '완드'

# %%
# 무기류 두번째 줄
driver.find_element(By.CSS_SELECTOR, 'ul:nth-child(2) > li:nth-child(11) > span').text
# Out:
# '채광/채집'

# %%
weapon_set1 = driver.find_element(By.CSS_SELECTOR, 'ul:nth-child(1) > li:nth-child(11) > span > a').text

# %%
driver.find_element(By.CSS_SELECTOR, 'tr:nth-child(2) > td.left.name > a > span').text
# Out:
# '낡은 글라디우스'

# %%
driver.find_element(By.CSS_SELECTOR, 'tr:nth-child(133) > td.left.name > a > span').text
# Out:
# '라이온하트 커틀러스'

# %%
driver.find_element(By.CSS_SELECTOR, 'tr:nth-child(1) > td.left.name > a > span').text
# Out:
# '메이플 1500일 깃발'

# %%
driver.find_element(By.CSS_SELECTOR, '#mapleDbItemTop > div > div.menuGroup.textMenu.textMenu1 > div > div > div > div > div > div > table > tbody > tr:nth-child(1) > td > div > div > ul:nth-child(1)')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="b37cc2a708f1f8224fc56ba03f93e4b3", element="4606efd6-d1ed-4cbd-91ba-6bbed41a8d28")>

# %%
onehand_level = driver.find_element(By.CSS_SELECTOR, 'tr:nth-child(1) > td:nth-child(3)').text
onehand_level
# Out:
# '0'

# %%
driver.find_element(By.CSS_SELECTOR, 'tr:nth-child(11) > td:nth-child(3)').text
# Out:
# '0'

# %%
driver.find_element(By.CSS_SELECTOR, '#mapleDbItemList > div > div.w710M > div > div > table > tbody > tr:nth-child(3) > td:nth-child(3)').text
# Out:
# '0'

# %%
'''
weapon = []
job = driver.find_element(By.CSS_SELECTOR, 'dl.reqjobgroups > dd > span').text
equipment_c = driver.find_element(By.CSS_SELECTOR, 'dl.equipGroup > dd > dl.itemclass').text
price = driver.find_element(By.CSS_SELECTOR, 'dl.addinfoGroup > dd > dl').text

try:
    driver.find_element(By.CSS_SELECTOR, 'dl.equipGroup > dd > dl.attackdelay').text
    attackspeed = driver.find_element(By.CSS_SELECTOR, 'dl.equipGroup > dd > dl.attackdelay').text
except:
    attackspeed = 'NaN'  

try:
    driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(1)').text
    physicalattack = driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(1)').text.split()[2]

except:
    physicalattack = 'NaN' 

weapon.append({
        '직업제한' : job.split(),
        '장비분류' : equipment_c,
        '공격속도' : attackspeed,
        '물리공격성' : physicalattack})
'''
# Out:
# "\nweapon = []\njob = driver.find_element(By.CSS_SELECTOR, 'dl.reqjobgroups > dd > span').text\nequipment_c = driver.find_element(By.CSS_SELECTOR, 'dl.equipGroup > dd > dl.itemclass').text\nprice = driver.find_element(By.CSS_SELECTOR, 'dl.addinfoGroup > dd > dl').text\n\ntry:\n    driver.find_element(By.CSS_SELECTOR, 'dl.equipGroup > dd > dl.attackdelay').text\n    attackspeed = driver.find_element(By.CSS_SELECTOR, 'dl.equipGroup > dd > dl.attackdelay').text\nexcept:\n    attackspeed = 'NaN'  \n\ntry:\n    driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(1)').text\n    physicalattack = driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(1)').text.split()[2]\n\nexcept:\n    physicalattack = 'NaN' \n\nweapon.append({\n        '직업제한' : job.split(),\n        '장비분류' : equipment_c,\n        '공격속도' : attackspeed,\n        '물리공격성' : physicalattack})\n"

# %%
'''
weaponlist = []
import time
from tqdm import tqdm_notebook

for i in tqdm_notebook(range(0, 133)):
    firststep = driver.find_element(By.CSS_SELECTOR, 'ul:nth-child(1) > li:nth-child(1) > span > a')
    firststep.click()
    onehand_forhead = f'tr:nth-child({i + 1}) > td.left.name > a > span'
    onehand = driver.find_element(By.CSS_SELECTOR, onehand_forhead).text
    onehand_level_for = f'tr:nth-child({i + 1}) > td:nth-child(3)'
    onehand_level = driver.find_element(By.CSS_SELECTOR, onehand_level_for).text
    detail_page = driver.find_element(By.CSS_SELECTOR, onehand_forhead)
    detail_page.click()
    
    job = driver.find_element(By.CSS_SELECTOR, 'dl.reqjobgroups > dd > span').text
    equipment_c = driver.find_element(By.CSS_SELECTOR, 'dl.equipGroup > dd > dl.itemclass').text
    
    
    try:
        driver.find_element(By.CSS_SELECTOR, 'dl.addinfoGroup > dd > dl').text
        price = driver.find_element(By.CSS_SELECTOR, 'dl.addinfoGroup > dd > dl').text

    except:
        price = 'NaN'     

    try:
        driver.find_element(By.CSS_SELECTOR, 'dl.equipGroup > dd > dl.attackdelay').text
        attackspeed = driver.find_element(By.CSS_SELECTOR, 'dl.equipGroup > dd > dl.attackdelay').text

    except:
        attackspeed = 'NaN'    


    try:
        driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(1)').text
        physicalattack = driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(1)').text.split()[2]

    except:
        physicalattack = 'NaN'    
    

    try:
        driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(2)').text
        attribute2 = driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(2)').text
        
    except:
        attribute2 = 'NaN'
     

    try:
        driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(3)').text
        attribute3 = driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(3)').text
        
    except:
        attribute3 = 'NaN'
     
    

    try:
        driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(4)').text
        attribute4 = driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(4)').text
       
    except:
        attribute4 = 'NaN'
    
    try:
        driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(5)').text
        attribute5 = driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(5)').text
          
    except:
        attribute5 = 'NaN'
          
     
    try:
        driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(6)').text
        attribute6 = driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(6)').text
        
    except:
        attribute6 = 'NaN'   
    
    weaponlist.append({
        '아이템 이름' : onehand,
        '요구 레벨' : onehand_level,
        '직업제한' : job.split(),
        '장비분류' : equipment_c,
        '공격속도' : attackspeed,
        '물리공격성' : physicalattack,
        '기타 속성' : [attribute2, attribute3, attribute4, attribute5, attribute6],
        '가격' : price})
    driver.back()
    time.sleep(1)
    '''
# Out:
# "\nweaponlist = []\nimport time\nfrom tqdm import tqdm_notebook\n\nfor i in tqdm_notebook(range(0, 133)):\n    firststep = driver.find_element(By.CSS_SELECTOR, 'ul:nth-child(1) > li:nth-child(1) > span > a')\n    firststep.click()\n    onehand_forhead = f'tr:nth-child({i + 1}) > td.left.name > a > span'\n    onehand = driver.find_element(By.CSS_SELECTOR, onehand_forhead).text\n    onehand_level_for = f'tr:nth-child({i + 1}) > td:nth-child(3)'\n    onehand_level = driver.find_element(By.CSS_SELECTOR, onehand_level_for).text\n    detail_page = driver.find_element(By.CSS_SELECTOR, onehand_forhead)\n    detail_page.click()\n    \n    job = driver.find_element(By.CSS_SELECTOR, 'dl.reqjobgroups > dd > span').text\n    equipment_c = driver.find_element(By.CSS_SELECTOR, 'dl.equipGroup > dd > dl.itemclass').text\n    \n    \n    try:\n        driver.find_element(By.CSS_SELECTOR, 'dl.addinfoGroup > dd > dl').text\n        price = driver.find_element(By.CSS_SELECTOR, 'dl.addinfoGroup > dd > dl'
# ...

# %%
weaponlist2 = []
import time
from tqdm import tqdm_notebook

for idx in tqdm_notebook(range(0, 11)):
    weapon_set1_for = f'ul:nth-child(1) > li:nth-child(11) > span'
    weapon_set1 = driver.find_element(By.CSS_SELECTOR, weapon_set1_for)
    weapon_set1.click()
    
    for i in range(0, 133):
        firststep = driver.find_element(By.CSS_SELECTOR, 'ul:nth-child(1) > li:nth-child(1) > span > a')
        firststep.click()
        onehand_forhead = f'tr:nth-child({i + 1}) > td.left.name > a > span'
        onehand = driver.find_element(By.CSS_SELECTOR, onehand_forhead).text
        onehand_level_for = f'tr:nth-child({i + 1}) > td:nth-child(3)'
        onehand_level = driver.find_element(By.CSS_SELECTOR, onehand_level_for).text
        detail_page = driver.find_element(By.CSS_SELECTOR, onehand_forhead)
        detail_page.click()
        
        job = driver.find_element(By.CSS_SELECTOR, 'dl.reqjobgroups > dd > span').text
        equipment_c = driver.find_element(By.CSS_SELECTOR, 'dl.equipGroup > dd > dl.itemclass').text
    
    
        try:
            driver.find_element(By.CSS_SELECTOR, 'dl.addinfoGroup > dd > dl').text
            price = driver.find_element(By.CSS_SELECTOR, 'dl.addinfoGroup > dd > dl').text

        except:
            price = 'NaN'     

        try:
            driver.find_element(By.CSS_SELECTOR, 'dl.equipGroup > dd > dl.attackdelay').text
            attackspeed = driver.find_element(By.CSS_SELECTOR, 'dl.equipGroup > dd > dl.attackdelay').text

        except:
            attackspeed = 'NaN'    


        try:
            driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(1)').text
            physicalattack = driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(1)').text.split()[2]

        except:
            physicalattack = 'NaN'    
        

        try:
            driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(2)').text
            attribute2 = driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(2)').text
            
        except:
            attribute2 = 'NaN'
        

        try:
            driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(3)').text
            attribute3 = driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(3)').text
            
        except:
            attribute3 = 'NaN'
        
        

        try:
            driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(4)').text
            attribute4 = driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(4)').text
        
        except:
            attribute4 = 'NaN'
        
        try:
            driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(5)').text
            attribute5 = driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(5)').text
            
        except:
            attribute5 = 'NaN'
            
        
        try:
            driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(6)').text
            attribute6 = driver.find_element(By.CSS_SELECTOR, 'dl.itemoptions > dd > ul > li:nth-child(6)').text
            
        except:
            attribute6 = 'NaN'   
        
        weaponlist2.append({
            '아이템 이름' : onehand,
            '요구 레벨' : onehand_level,
            '직업제한' : job.split(),
            '장비분류' : equipment_c,
            '공격속도' : attackspeed,
            '물리공격성' : physicalattack,
            '기타 속성' : [attribute2, attribute3, attribute4, attribute5, attribute6],
            '가격' : price})
        driver.back()
        time.sleep(1)
    time.sleep(1)
# Out:
# C:\Users\TAEN\AppData\Local\Temp\ipykernel_3352\1664423682.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for idx in tqdm_notebook(range(0, 11)):
#   0%|          | 0/11 [00:00<?, ?it/s]

# %%
weaponlist2
# Out:
# [{'아이템 이름': '메이플 1500일 깃발',
#   '요구 레벨': '0',
#   '직업제한': ['초보자', '전사', '마법사', '궁수', '도적', '해적'],
#   '장비분류': '장비분류 :한손검',
#   '공격속도': '공격속도 :5',
#   '물리공격성': '+38',
#   '기타 속성': ['STR : +1', 'DEX : +1', 'INT : +1', 'LUK : +1', '이동속도 : +15'],
#   '가격': '가격 :1600'},
#  {'아이템 이름': '낡은 글라디우스',
#   '요구 레벨': '0',
#   '직업제한': ['초보자', '전사', '마법사', '궁수', '도적', '해적'],
#   '장비분류': '장비분류 :한손검',
#   '공격속도': '공격속도 :4',
#   '물리공격성': '+10',
#   '기타 속성': ['NaN', 'NaN', 'NaN', 'NaN', 'NaN'],
#   '가격': '가격 :1'},
#  {'아이템 이름': '신문지 칼',
#   '요구 레벨': '0',
#   '직업제한': ['초보자', '전사', '마법사', '궁수', '도적', '해적'],
#   '장비분류': '장비분류 :한손검',
#   '공격속도': '공격속도 :4',
#   '물리공격성': '+19',
#   '기타 속성': ['NaN', 'NaN', 'NaN', 'NaN', 'NaN'],
#   '가격': '가격 :200'},
#  {'아이템 이름': '메이플 1000일 깃발',
#   '요구 레벨': '0',
#   '직업제한': ['초보자', '전사', '마법사', '궁수', '도적', '해적'],
#   '장비분류': '장비분류 :한손검',
#   '공격속도': '공격속도 :4',
#   '물리공격성': '+22',
#   '기타 속성': ['STR : +1', 'DEX : +1', 'INT : +1', 'LUK : +1', '회피율 : +1'],
#   '가격': '가격 :300'},
# ...

# %%
import pandas as pd

# %%
weaponlist2 = pd.DataFrame(weaponlist2)
weaponlist2.tail()
# Out:
#           아이템 이름 요구 레벨                        직업제한       장비분류     공격속도 물리공격성  \
# 128  피어리스 엑서큐서너스   125  [초보자, 전사, 마법사, 궁수, 도적, 해적]  장비분류 :한손검  공격속도 :5  +116
# 129  빅터 반 레온 세이버   125  [초보자, 전사, 마법사, 궁수, 도적, 해적]  장비분류 :한손검  공격속도 :5  +116
# 130   어비스 엑서큐서너스   125  [초보자, 전사, 마법사, 궁수, 도적, 해적]  장비분류 :한손검  공격속도 :5  +113
# 131  아가레스 블러디 피어   130  [초보자, 전사, 마법사, 궁수, 도적, 해적]  장비분류 :한손검  공격속도 :5  +114
# 132   라이온하트 커틀러스   140  [초보자, 전사, 마법사, 궁수, 도적, 해적]  장비분류 :한손검  공격속도 :5  +131
#
#                                             기타 속성         가격
# 128          [STR : +11, DEX : +4, NaN, NaN, NaN]  가격 :70000
# 129          [STR : +6, 명중률 : +20, NaN, NaN, NaN]      가격 :1
# 130           [STR : +9, DEX : +4, NaN, NaN, NaN]  가격 :70000
# 131    [STR : +8, DEX : +4, 명중률 : +50, : +5, NaN]      가격 :1
# 132  [STR : +35, DEX : +20, 명중률 : +100, NaN, NaN]      가격 :1

# %%
pd.DataFrame(weaponlist2).to_excel('../source_code/maple_onehanded weapon list2.xlsx')

# %%
driver.find_element(By.CSS_SELECTOR, ' tr:nth-child(1) > td > div > div > ul:nth-child(2) > li:nth-child(1)').text
# Out:
# '스태프'
